# %%
import sys

print(sys.version)
print(sys.path)
print("---")
print(sys.executable)
# Out:
# 3.9.13 (main, Oct 13 2022, 16:12:30)
# [Clang 12.0.0 ]
# ['/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/notebook', '/Users/eduardo/opt/anaconda3/envs/practica0/lib/python39.zip', '/Users/eduardo/opt/anaconda3/envs/practica0/lib/python3.9', '/Users/eduardo/opt/anaconda3/envs/practica0/lib/python3.9/lib-dynload', '', '/Users/eduardo/opt/anaconda3/envs/practica0/lib/python3.9/site-packages']
# ---
# /Users/eduardo/opt/anaconda3/envs/practica0/bin/python

# %% [raw]
# LIBRERIAS

# %%
# primero todas las librerías por bloques
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# opciones de visualización
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df1 = pd.read_csv("/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/data/raw/Loan_test_set.csv", skiprows=[0])
df2 = pd.read_csv("/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/data/raw/Loan_training_set_1_4.csv", skiprows=[0])
df3 = pd.read_csv("/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/data/raw/Loan_training_set_2_4.csv", skiprows=[0])
df4 = pd.read_csv("/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/data/raw/Loan_training_set_3_4.csv", skiprows=[0])
df5 = pd.read_csv("/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/data/raw/Loan_training_set_4_4.csv", skiprows=[0])

# %%
# Tendré que juntarlo pero separando training y test
df1['test_set'] = 1
df2['test_set'] = 0
df3['test_set'] = 0
df4['test_set'] = 0
df5['test_set'] = 0

# %%
columns = np.dstack((list(df1.columns), list(df2.columns), list(df3.columns), list(df4.columns), list(df5.columns)))

# %%
coldf = pd.DataFrame(columns[0])

# %%
coldf.head()
# Out:
#                  0                1                2                3  \
# 0               id               id               id               id
# 1        member_id        member_id        member_id        member_id
# 2        loan_amnt        loan_amnt        loan_amnt        loan_amnt
# 3      funded_amnt      funded_amnt      funded_amnt      funded_amnt
# 4  funded_amnt_inv  funded_amnt_inv  funded_amnt_inv  funded_amnt_inv
#
#                  4
# 0               id
# 1        member_id
# 2        loan_amnt
# 3      funded_amnt
# 4  funded_amnt_inv

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.shape
# Out:
# (981665, 151)

# %%
print(list(df.columns))
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'disbursement_method', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %%
df.head(5)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  104046719        NaN    14000.0      14000.0          14000.0   36 months
# 1  104048967        NaN     5000.0       5000.0           5000.0   36 months
# 2  104028593        NaN     4600.0       4600.0           4600.0   36 months
# 3  104046702        NaN    14000.0      14000.0          14000.0   60 months
# 4  104280113        NaN    15000.0      15000.0          15000.0   36 months
#
#   int_rate  installment grade sub_grade                  emp_title emp_length  \
# 0   15.99%       492.13     C        C5             Project Leader  10+ years
# 1   25.49%       200.10     E        E4                      Pilot  10+ years
# 2   11.39%       151.45     B        B3           cable technician    4 years
# 3   12.74%       316.69     C        C1            Specialty Sales    4 years
# 4    5.32%       451.73     A        A1  Executive Account Manager  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAGE     82000.0     Source Verified  Mar-2017     Current
# 1       MORTGAGE    215000.0     Source Verified  Mar-2017     Current
# 2           RENT     44470.0        Not Verified  Mar-2017     Current
# 3            OWN     40000.0        Not Verified  Mar-2017     Current
# 4       MORTGAGE    182000.0        Not Verified  Mar-2017     Current
#
#   pymnt_plan                                                url desc  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 3          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 4          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#               purpose                    title zip_code addr_state    dti  \
# 0         credit_card  Credit card refinancing    672xx         KS  31.07
# 1  debt_consolidation       Debt consolidation    067xx         CT   6.06
# 2         credit_card  Credit card refinancing    066xx         CT  13.43
# 3         credit_card  Credit card refinancing    926xx         CA  17.48
# 4  debt_consolidation       Debt consolidation    751xx         TX   9.35
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         May-1996           725.0            729.0
# 1          0.0         Jan-2004           765.0            769.0
# 2          0.0         Dec-2003           770.0            774.0
# 3          0.0         Feb-1974           715.0            719.0
# 4          0.0         Nov-1974           740.0            744.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                     NaN                     NaN      18.0
# 1             4.0                     NaN                     NaN      11.0
# 2             1.0                     NaN                     NaN       7.0
# 3             0.0                     NaN                     NaN      10.0
# 4             0.0                     NaN                     NaN      13.0
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0    69578.0      63.2%       31.0                   w   11438.26
# 1      0.0     8678.0      18.8%       16.0                   f    4190.59
# 2      0.0     5400.0      19.1%       11.0                   w    3708.50
# 3      0.0    25787.0      46.2%       23.0                   w   12604.51
# 4      0.0    34623.0      33.7%       32.0                   w   11869.91
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0       11438.26      3912.17          3912.17          2561.74
# 1        4190.59      1586.64          1586.64           809.41
# 2        3708.50      1205.78          1205.78           891.50
# 3       12604.51      2585.32          2585.32          1395.49
# 4       11869.91      3604.97          3604.97          3130.09
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0        1350.43                 0.0         0.0                      0.0
# 1         777.23                 0.0         0.0                      0.0
# 2         314.28                 0.0         0.0                      0.0
# 3        1189.83                 0.0         0.0                      0.0
# 4         474.88                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Dec-2017           492.13     Jan-2018           Dec-2017
# 1     Dec-2017           200.10     Jan-2018           Dec-2017
# 2     Dec-2017           151.45     Jan-2018           Dec-2017
# 3     Dec-2017           316.69     Jan-2018           Dec-2017
# 4     Dec-2017           451.73     Jan-2018           Dec-2017
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 714.0                710.0                         0.0
# 1                 779.0                775.0                         0.0
# 2                 769.0                765.0                         0.0
# 3                 714.0                710.0                         0.0
# 4                 734.0                730.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           0.0     202617.0          0.0          3.0          0.0
# 1           0.0      44754.0          1.0          3.0          2.0
# 2           0.0       9625.0          1.0          1.0          0.0
# 3           0.0      25787.0          2.0          0.0          0.0
# 4           0.0     233521.0          0.0          1.0          0.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                22.0       34430.0     57.0          0.0
# 1          4.0                 7.0       35832.0     68.0          2.0
# 2          1.0                22.0        4225.0     36.0          2.0
# 3          0.0               129.0           0.0      NaN          5.0
# 4          1.0                24.0        2667.0     59.0          2.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          2.0     13686.0      61.0          110037.0     0.0          9.0
# 1          2.0      8659.0      27.0           46200.0     2.0          0.0
# 2          4.0      4670.0      24.0           28300.0     0.0          0.0
# 3          7.0      8549.0      46.0           55800.0     0.0          3.0
# 4          2.0     12503.0      42.0          102600.0     1.0          6.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   3.0      11257.0         29762.0     63.4
# 1           6.0                   6.0       4069.0         37522.0     18.8
# 2           1.0                   5.0       1375.0          9610.0     33.7
# 3           0.0                   7.0       2579.0         27153.0     48.3
# 4           0.0                   4.0      17963.0         55203.0     26.0
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               140.0
# 1                       0.0          0.0                83.0
# 2                       0.0          0.0                77.0
# 3                       0.0          0.0               129.0
# 4                       0.0          0.0                92.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 250.0                   13.0            13.0       6.0
# 1                  87.0                    5.0             5.0       0.0
# 2                 159.0                    1.0             1.0       0.0
# 3                 517.0                    1.0             1.0       1.0
# 4                 508.0                    8.0             8.0       5.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                  13.0                       NaN                   13.0
# 1                   5.0                       NaN                    0.0
# 2                   7.0                       NaN                    1.0
# 3                   2.0                       NaN                   23.0
# 4                   8.0                       NaN                   17.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    0.0             7.0
# 1                             NaN                    0.0             2.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             7.0
# 4                             NaN                    0.0             3.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              9.0          8.0       13.0        4.0           14.0
# 1              2.0          7.0        8.0        7.0            7.0
# 2              3.0          3.0        4.0        2.0            6.0
# 3              9.0          8.0       13.0        1.0           10.0
# 4              6.0          7.0       11.0        9.0           10.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0           21.0                  9.0      18.0               0.0
# 1            8.0                  2.0      11.0               0.0
# 2            9.0                  3.0       7.0               0.0
# 3           21.0                  9.0      10.0               0.0
# 4           16.0                  6.0      13.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0           100.0
# 1           0.0                 0.0                 4.0           100.0
# 2           0.0                 0.0                 2.0           100.0
# 3           0.0                 0.0                 5.0           100.0
# 4           0.0                 0.0                 2.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              25.0                   0.0        0.0         286204.0
# 1               0.0                   0.0        0.0         100763.0
# 2               0.0                   0.0        0.0          40000.0
# 3              37.5                   0.0        0.0          55800.0
# 4               0.0                   0.0        0.0         325464.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0           104008.0         81400.0                     60167.0
# 1            44754.0         46200.0                     49814.0
# 2             9625.0         14500.0                     11700.0
# 3            25787.0         52500.0                         0.0
# 4            50766.0         74600.0                      4508.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.dtypes.sort_values().to_frame('feature_type').groupby(by = 'feature_type').size().to_frame('count').reset_index()
# Out:
#   feature_type  count
# 0      float64    111
# 1       object     40

# %%
# Analizar una variable concreta
df.loan_status.value_counts()
# Out:
# Current               500937
# Fully Paid            358629
# Charged Off            99099
# Late (31-120 days)     13203
# In Grace Period         6337
# Late (16-30 days)       3414
# Default                   36
# Name: loan_status, dtype: int64

# %%
# analizar nulos
df_dtypes = pd.merge(df.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index(),
         df.dtypes.to_frame('feature_type').reset_index(),
         on = 'index',
         how = 'inner')

# %%
df_dtypes.sort_values(['missing_value', 'feature_type'])
# Out:
#                                           index  missing_value feature_type
# 0                                            id              0       object
# 1                                   tot_cur_bal             10      float64
# 2                                  tot_coll_amt             10      float64
# 3                                acc_now_delinq             10      float64
# 4                               tot_hi_cred_lim             10      float64
# 5                             total_bal_ex_mort             10      float64
# 6                                total_bc_limit             10      float64
# 8                                   policy_code             10      float64
# 9                    total_il_high_credit_limit             10      float64
# 10                   collections_12_mths_ex_med             10      float64
# 11                          last_fico_range_low             10      float64
# 12                         last_fico_range_high             10      float64
# 13                              last_pymnt_amnt             10      float64
# 14                               num_actv_bc_tl             10      float64
# 15                      collection_recovery_fee             10      float64
# 16                                   recoveries             10      float64
# 17                           total_rec_late_fee             10      float64
# 18                                    tax_liens             10      float64
# 19                                total_rec_int             10      float64
# 20                         pub_rec_bankruptcies             10      float64
# 21                           num_tl_op_past_12m             10      float64
# 22                        num_accts_ever_120_pd             10      float64
# 23                                  num_bc_sats             10      float64
# 24                                     mort_acc             10      float64
# 25                               mo_sin_rcnt_tl             10      float64
# 26                        mo_sin_rcnt_rev_tl_op             10      float64
# 27                         mo_sin_old_rev_tl_op             10      float64
# 28                                  delinq_amnt             10      float64
# 29                     chargeoff_within_12_mths             10      float64
# 30                         acc_open_past_24mths             10      float64
# 31                                    num_bc_tl             10      float64
# 32                                    num_il_tl             10      float64
# 33                                num_op_rev_tl             10      float64
# 34                             total_rev_hi_lim             10      float64
# 35                          num_rev_tl_bal_gt_0             10      float64
# 36                                     num_sats             10      float64
# 37                                 num_tl_30dpd             10      float64
# 38                           num_tl_90g_dpd_24m             10      float64
# 39                               pct_tl_nvr_dlq             10      float64
# 40                              total_rec_prncp             10      float64
# 41                              num_actv_rev_tl             10      float64
# 42                                  total_pymnt             10      float64
# 44                              total_pymnt_inv             10      float64
# 48                                   annual_inc             10      float64
# 52                                  installment             10      float64
# 55                              funded_amnt_inv             10      float64
# 56                                  funded_amnt             10      float64
# 57                                    loan_amnt             10      float64
# 62                                      pub_rec             10      float64
# 63                                out_prncp_inv             10      float64
# 64                                    out_prncp             10      float64
# 66                                  delinq_2yrs             10      float64
# 68                               fico_range_low             10      float64
# 69                              fico_range_high             10      float64
# 70                                    total_acc             10      float64
# 71                               inq_last_6mths             10      float64
# 72                                    revol_bal             10      float64
# 75                                     open_acc             10      float64
# 7                              application_type             10       object
# 43                                          url             10       object
# 45                                  loan_status             10       object
# 46                                      issue_d             10       object
# 47                          verification_status             10       object
# 49                               home_ownership             10       object
# 50                          disbursement_method             10       object
# 51                                    sub_grade             10       object
# 53                                     int_rate             10       object
# 54                                         term             10       object
# 58                         debt_settlement_flag             10       object
# 59                                        grade             10       object
# 60                                      purpose             10       object
# 61                                   pymnt_plan             10       object
# 65                          initial_list_status             10       object
# 67                             earliest_cr_line             10       object
# 73                                   addr_state             10       object
# 74                                hardship_flag             10       object
# 77                                num_rev_accts             11      float64
# 76                                     zip_code             11       object
# 78                                  avg_cur_bal             23      float64
# 79                           last_credit_pull_d             50       object
# 80                                        title            142       object
# 81                                          dti            304      float64
# 82                                   revol_util            550       object
# 83                                 last_pymnt_d            878       object
# 84                         mths_since_recent_bc           9718      float64
# 85                               bc_open_to_buy          10282      float64
# 86                             percent_bc_gt_75          10677      float64
# 87                                      bc_util          10862      float64
# 88                           mo_sin_old_il_acct          28220      float64
# 89                             num_tl_120dpd_2m          42519      float64
# 90                                   emp_length          57995       object
# 91                                    emp_title          59595       object
# 92                        mths_since_recent_inq         103454      float64
# 93                                 next_pymnt_d         457738       object
# 94                       mths_since_last_delinq         477730      float64
# 95               mths_since_recent_revol_delinq         631372      float64
# 96                                       inq_fi         635362      float64
# 97                                 inq_last_12m         635362      float64
# 98                                  open_acc_6m         635362      float64
# 99                                  open_act_il         635362      float64
# 100                                 open_il_24m         635362      float64
# 101                                total_bal_il         635362      float64
# 102                                 open_rv_12m         635362      float64
# 103                                 open_il_12m         635362      float64
# 104                                  max_bal_bc         635362      float64
# 105                                 total_cu_tl         635362      float64
# 106                                 open_rv_24m         635362      float64
# 107                                    all_util         635392      float64
# 108                          mths_since_rcnt_il         644709      float64
# 109                                     il_util         681303      float64
# 110                 mths_since_last_major_derog         702961      float64
# 111                    mths_since_recent_bc_dlq         732439      float64
# 112                      mths_since_last_record         807460      float64
# 114                            annual_inc_joint         955940      float64
# 113                   verification_status_joint         955940       object
# 115                                   dti_joint         955942      float64
# 116          sec_app_collections_12_mths_ex_med         959840      float64
# 117            sec_app_chargeoff_within_12_mths         959840      float64
# 118                       sec_app_num_rev_accts         959840      float64
# 119                            sec_app_open_acc         959840      float64
# 120                         sec_app_open_act_il         959840      float64
# 121                      sec_app_inq_last_6mths         959840      float64
# 123                     sec_app_fico_range_high         959840      float64
# 124                      sec_app_fico_range_low         959840      float64
# 125                             revol_bal_joint         959840      float64
# 126                            sec_app_mort_acc         959840      float64
# 122                    sec_app_earliest_cr_line         959840       object
# 127                          sec_app_revol_util         960128      float64
# 128                                        desc         966341       object
# 129                           settlement_amount         973035      float64
# 133                             settlement_term         973035      float64
# 134                       settlement_percentage         973035      float64
# 130                             settlement_date         973035       object
# 131                           settlement_status         973035       object
# 132                   debt_settlement_flag_date         973035       object
# 135         sec_app_mths_since_last_major_derog         974124      float64
# 140                             hardship_amount         978661      float64
# 141                hardship_last_payment_amount         978661      float64
# 143                                hardship_dpd         978661      float64
# 144                             hardship_length         978661      float64
# 146                               deferral_term         978661      float64
# 147              hardship_payoff_balance_amount         978661      float64
# 136                         hardship_start_date         978661       object
# 137                               hardship_type         978661       object
# 138                             hardship_reason         978661       object
# 139                             hardship_status         978661       object
# 142                        hardship_loan_status         978661       object
# 145                     payment_plan_start_date         978661       object
# 148                           hardship_end_date         978661       object
# 149  orig_projected_additional_accrued_interest         979086      float64
# 150                                   member_id         981665      float64

# %%
# Check columns have more than  400000  missing values ( ≈90% )
missing_df = df.isnull().sum(axis = 0).sort_values().to_frame('missing_value').reset_index()

# %%
miss_4000 = list(missing_df[missing_df.missing_value >= 400000]['index'])

# %%
print(len(miss_4000))
# Out:
# 58

# %%
print(sorted(miss_4000))
# Out:
# ['all_util', 'annual_inc_joint', 'debt_settlement_flag_date', 'deferral_term', 'desc', 'dti_joint', 'hardship_amount', 'hardship_dpd', 'hardship_end_date', 'hardship_last_payment_amount', 'hardship_length', 'hardship_loan_status', 'hardship_payoff_balance_amount', 'hardship_reason', 'hardship_start_date', 'hardship_status', 'hardship_type', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'member_id', 'mths_since_last_delinq', 'mths_since_last_major_derog', 'mths_since_last_record', 'mths_since_rcnt_il', 'mths_since_recent_bc_dlq', 'mths_since_recent_revol_delinq', 'next_pymnt_d', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 'orig_projected_additional_accrued_interest', 'payment_plan_start_date', 'revol_bal_joint', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_earliest_cr_line', 'sec_app_fico_range_high', 'sec_app_fico_range_low', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_mths_since_last_major_derog', 'sec_app_num_rev_accts', 'sec_app_open_acc', 'sec_app_open_act_il', 'sec_app_revol_util', 'settlement_amount', 'settlement_date', 'settlement_percentage', 'settlement_status', 'settlement_term', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']

# %%
# también puede haber columnas duplicadas y observa cómo encapsulamos el código en FUNCIONES
def duplicate_columns(frame):
    groups = frame.columns.to_series().groupby(frame.dtypes).groups
    dups = []

    for t, v in groups.items():

        cs = frame[v].columns
        vs = frame[v]
        lcs = len(cs)

        for i in range(lcs):
            ia = vs.iloc[:,i].values
            for j in range(i+1, lcs):
                ja = vs.iloc[:,j].values
                if np.array_equal(ia, ja):
                    dups.append(cs[i])
                    break
    return dups

# %%
duplicate_cols = duplicate_columns(df)

# %%
duplicate_cols
# Out:
# []

# %%
df.shape
# Out:
# (981665, 151)

# %% [markdown]
# Podemos analizar también variables a nivel individual

# %%
def plot_feature(col_name, isContinuous):
    """
    Visualize a variable with and without faceting on the loan status.
    - col_name is the variable name in the dataframe
    - full_name is the full variable name
    - continuous is True if the variable is continuous, False otherwise
    """
    f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)
    
    # Plot without loan status
    if isContinuous:
        sns.distplot(df.loc[df[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(df[col_name], order=sorted(df[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(col_name)
    ax1.set_ylabel('Count')
    ax1.set_title(col_name)
    plt.xticks(rotation = 90)

    # Plot with loan status
    if isContinuous:
        sns.boxplot(x=col_name, y='loan_status', data=df, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(col_name + ' by Loan Status')
    else:
        data = df.groupby(col_name)['loan_status'].value_counts(normalize=True).to_frame('proportion').reset_index()        
        sns.barplot(x = col_name, y = 'proportion', hue= "loan_status", data = data, saturation=1, ax=ax2)
        ax2.set_ylabel('Loan fraction')
        ax2.set_title('Loan status')
        plt.xticks(rotation = 90)
    ax2.set_xlabel(col_name)
    
    plt.tight_layout()

# %%
plot_feature('loan_amnt', True)

# %%
df.describe()
# Out:
#        member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count        0.0  981655.000000  981655.000000    981655.000000
# mean         NaN   14963.557767   14963.557767     14958.494068
# std          NaN    8864.677646    8864.677646      8861.664737
# min          NaN    1000.000000    1000.000000       900.000000
# 25%          NaN    8000.000000    8000.000000      8000.000000
# 50%          NaN   13000.000000   13000.000000     13000.000000
# 75%          NaN   20000.000000   20000.000000     20000.000000
# max          NaN   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc            dti    delinq_2yrs  \
# count  981655.000000  9.816550e+05  981361.000000  981655.000000
# mean      441.567492  7.766029e+04      18.878278       0.348926
# std       257.896445  1.452782e+05      11.822292       0.929949
# min        14.010000  0.000000e+00      -1.000000       0.000000
# 25%       255.450000  4.650000e+04      12.320000       0.000000
# 50%       377.510000  6.500000e+04      18.190000       0.000000
# 75%       582.350000  9.240000e+04      24.720000       0.000000
# max      1719.830000  1.100000e+08     999.000000      42.000000
#
#        fico_range_low  fico_range_high  inq_last_6mths  \
# count   981655.000000    981655.000000   981655.000000
# mean       694.888999       698.889131        0.595004
# std         31.052538        31.053181        0.896238
# min        660.000000       664.000000        0.000000
# 25%        670.000000       674.000000        0.000000
# 50%        685.000000       689.000000        0.000000
# 75%        710.000000       714.000000        1.000000
# max        845.000000       850.000000        6.000000
#
#        mths_since_last_delinq  mths_since_last_record       open_acc  \
# count           503935.000000           174205.000000  981655.000000
# mean                33.648506               69.144181      11.816029
# std                 21.902016               26.371930       5.600335
# min                  0.000000                0.000000       0.000000
# 25%                 15.000000               51.000000       8.000000
# 50%                 30.000000               70.000000      11.000000
# 75%                 49.000000               88.000000      15.000000
# max                188.000000              121.000000      93.000000
#
#              pub_rec     revol_bal      total_acc      out_prncp  \
# count  981655.000000  9.816550e+05  981655.000000  981655.000000
# mean        0.230210  1.700362e+04      24.999027    5414.467766
# std         0.632749  2.309086e+04      12.009993    7732.201869
# min         0.000000  0.000000e+00       2.000000       0.000000
# 25%         0.000000  6.229000e+03      16.000000       0.000000
# 50%         0.000000  1.162900e+04      23.000000    1156.760000
# 75%         0.000000  2.070800e+04      32.000000    8872.570000
# max        86.000000  2.904836e+06     169.000000   40000.000000
#
#        out_prncp_inv    total_pymnt  total_pymnt_inv  total_rec_prncp  \
# count  981655.000000  981655.000000    981655.000000    981655.000000
# mean     5412.834903   10759.329230     10755.536718      8402.339152
# std      7730.071882    9380.494413      9377.202323      7961.514874
# min         0.000000       0.000000         0.000000         0.000000
# 25%         0.000000    3259.195868      3258.380000      2030.270000
# 50%      1156.620000    8236.280000      8233.170000      6000.000000
# 75%      8868.050000   15584.175704     15577.320000     12000.000000
# max     40000.000000   60179.739076     60179.740000     40000.000000
#
#        total_rec_int  total_rec_late_fee     recoveries  \
# count  981655.000000        9.816550e+05  981655.000000
# mean     2251.174242        9.008020e-01     104.915034
# std      2493.168743        7.342317e+00     615.556027
# min         0.000000       -9.500000e-09       0.000000
# 25%       631.675000        0.000000e+00       0.000000
# 50%      1388.420000        0.000000e+00       0.000000
# 75%      2916.655000        0.000000e+00       0.000000
# max     26082.830000        5.320800e+02   36578.540000
#
#        collection_recovery_fee  last_pymnt_amnt  last_fico_range_high  \
# count            981655.000000    981655.000000         981655.000000
# mean                 17.860589      3114.646693            687.342490
# std                 107.546193      5782.015117             68.563702
# min                   0.000000         0.000000              0.000000
# 25%                   0.000000       301.150000            659.000000
# 50%                   0.000000       530.610000            694.000000
# 75%                   0.000000      2541.770000            729.000000
# max                6584.137200     41453.070000            850.000000
#
#        last_fico_range_low  collections_12_mths_ex_med  \
# count        981655.000000               981655.000000
# mean            676.984434                    0.019997
# std             101.006471                    0.156749
# min               0.000000                    0.000000
# 25%             655.000000                    0.000000
# 50%             690.000000                    0.000000
# 75%             725.000000                    0.000000
# max             845.000000                   20.000000
#
#        mths_since_last_major_derog  policy_code  annual_inc_joint  \
# count                278704.000000     981655.0      2.572500e+04
# mean                     44.456757          1.0      1.171532e+05
# std                      22.369926          0.0      5.636689e+04
# min                       0.000000          1.0      1.585000e+04
# 25%                      27.000000          1.0      8.100000e+04
# 50%                      44.000000          1.0      1.070000e+05
# 75%                      62.000000          1.0      1.400000e+05
# max                     188.000000          1.0      1.210000e+06
#
#           dti_joint  acc_now_delinq  tot_coll_amt   tot_cur_bal  \
# count  25723.000000   981655.000000  9.816550e+05  9.816550e+05
# mean      18.936393        0.005909  2.532014e+02  1.421102e+05
# std        7.172047        0.083246  9.503410e+03  1.577753e+05
# min        0.000000        0.000000  0.000000e+00  0.000000e+00
# 25%       13.740000        0.000000  0.000000e+00  3.022200e+04
# 50%       18.680000        0.000000  0.000000e+00  8.098700e+04
# 75%       23.980000        0.000000  0.000000e+00  2.117820e+05
# max       61.900000       14.000000  9.152545e+06  8.524709e+06
#
#          open_acc_6m    open_act_il    open_il_12m    open_il_24m  \
# count  346303.000000  346303.000000  346303.000000  346303.000000
# mean        0.903013       2.863134       0.626801       1.539759
# std         1.110607       3.064717       0.853855       1.519747
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       1.000000       0.000000       0.000000
# 50%         1.000000       2.000000       0.000000       1.000000
# 75%         1.000000       3.000000       1.000000       2.000000
# max        16.000000      57.000000      12.000000      23.000000
#
#        mths_since_rcnt_il  total_bal_il        il_util    open_rv_12m  \
# count       336956.000000  3.463030e+05  300362.000000  346303.000000
# mean            21.321822  3.595931e+04      68.931965       1.300988
# std             25.636453  4.409079e+04      24.168541       1.500120
# min              0.000000  0.000000e+00       0.000000       0.000000
# 25%              7.000000  9.183500e+03      54.000000       0.000000
# 50%             14.000000  2.351700e+04      71.000000       1.000000
# 75%             24.000000  4.651150e+04      85.000000       2.000000
# max            433.000000  1.711009e+06     464.000000      28.000000
#
#          open_rv_24m     max_bal_bc       all_util  total_rev_hi_lim  \
# count  346303.000000  346303.000000  346273.000000      9.816550e+05
# mean        2.791010    5819.417343      58.188109      3.340459e+04
# std         2.610873    5492.858560      20.775971      3.672598e+04
# min         0.000000       0.000000       0.000000      0.000000e+00
# 25%         1.000000    2382.000000      44.000000      1.420000e+04
# 50%         2.000000    4468.000000      59.000000      2.450000e+04
# 75%         4.000000    7581.000000      73.000000      4.160000e+04
# max        54.000000  571793.000000     211.000000      9.999999e+06
#
#               inq_fi    total_cu_tl   inq_last_12m  acc_open_past_24mths  \
# count  346303.000000  346303.000000  346303.000000         981655.000000
# mean        0.970200       1.451963       2.045968              4.576213
# std         1.461146       2.632077       2.334894              3.127835
# min         0.000000       0.000000       0.000000              0.000000
# 25%         0.000000       0.000000       0.000000              2.000000
# 50%         0.000000       0.000000       1.000000              4.000000
# 75%         1.000000       2.000000       3.000000              6.000000
# max        27.000000      71.000000      41.000000             64.000000
#
#          avg_cur_bal  bc_open_to_buy        bc_util  chargeoff_within_12_mths  \
# count  981642.000000   971383.000000  970803.000000             981655.000000
# mean    13418.176272    10139.309019      60.873200                  0.010062
# std     16054.693988    15316.937766      27.798187                  0.114348
# min         0.000000        0.000000       0.000000                  0.000000
# 25%      3154.000000     1442.000000      39.700000                  0.000000
# 50%      7406.000000     4647.000000      64.100000                  0.000000
# 75%     18574.750000    12324.000000      85.300000                  0.000000
# max    710392.000000   559912.000000     318.200000                 10.000000
#
#          delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# count  981655.000000       953445.000000         981655.000000
# mean       14.144151          127.182896            184.614423
# std       785.108510           52.548613             95.962800
# min         0.000000            0.000000              1.000000
# 25%         0.000000          100.000000            119.000000
# 50%         0.000000          130.000000            167.000000
# 75%         0.000000          154.000000            235.000000
# max    249925.000000          999.000000            999.000000
#
#        mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl       mort_acc  \
# count          981655.000000   981655.000000  981655.000000
# mean               13.594001        8.121912       1.639821
# std                17.090145        8.984623       1.968093
# min                 0.000000        0.000000       0.000000
# 25%                 4.000000        3.000000       0.000000
# 50%                 8.000000        6.000000       1.000000
# 75%                16.000000       10.000000       3.000000
# max               372.000000      263.000000      94.000000
#
#        mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# count         971947.000000             249226.000000          878211.000000
# mean              24.604214                 38.963270               6.889997
# std               31.880584                 22.771086               5.932802
# min                0.000000                  0.000000               0.000000
# 25%                6.000000                 20.000000               2.000000
# 50%               14.000000                 37.000000               5.000000
# 75%               29.000000                 58.000000              10.000000
# max              616.000000                195.000000              25.000000
#
#        mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# count                   350293.000000          981655.000000   981655.000000
# mean                        35.166389               0.527219        3.708004
# std                         22.423296               1.369052        2.291576
# min                          0.000000               0.000000        0.000000
# 25%                         16.000000               0.000000        2.000000
# 50%                         32.000000               0.000000        3.000000
# 75%                         51.000000               0.000000        5.000000
# max                        180.000000              45.000000       36.000000
#
#        num_actv_rev_tl    num_bc_sats      num_bc_tl      num_il_tl  \
# count    981655.000000  981655.000000  981655.000000  981655.000000
# mean          5.764184       4.761372       7.956300       8.590451
# std           3.373387       2.994027       4.751942       7.416321
# min           0.000000       0.000000       0.000000       0.000000
# 25%           3.000000       3.000000       5.000000       4.000000
# 50%           5.000000       4.000000       7.000000       7.000000
# 75%           7.000000       6.000000      10.000000      11.000000
# max          63.000000      63.000000      77.000000     150.000000
#
#        num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0       num_sats  \
# count  981655.000000  981654.000000        981655.000000  981655.000000
# mean        8.322311      14.508668             5.706391      11.766086
# std         4.624774       8.144363             3.285521       5.584926
# min         0.000000       2.000000             0.000000       0.000000
# 25%         5.000000       9.000000             3.000000       8.000000
# 50%         7.000000      13.000000             5.000000      11.000000
# 75%        11.000000      19.000000             7.000000      15.000000
# max        91.000000     143.000000            45.000000      93.000000
#
#        num_tl_120dpd_2m   num_tl_30dpd  num_tl_90g_dpd_24m  \
# count     939146.000000  981655.000000       981655.000000
# mean           0.000875       0.003885            0.094050
# std            0.032060       0.065792            0.525655
# min            0.000000       0.000000            0.000000
# 25%            0.000000       0.000000            0.000000
# 50%            0.000000       0.000000            0.000000
# 75%            0.000000       0.000000            0.000000
# max            7.000000       4.000000           42.000000
#
#        num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count       981655.000000   981655.000000     970988.000000
# mean             2.091457       93.864404         45.967467
# std              1.790000        9.077672         36.017697
# min              0.000000        0.000000          0.000000
# 25%              1.000000       90.900000         12.500000
# 50%              2.000000       97.500000         50.000000
# 75%              3.000000      100.000000         75.000000
# max             30.000000      100.000000        100.000000
#
#        pub_rec_bankruptcies      tax_liens  tot_hi_cred_lim  \
# count         981655.000000  981655.000000     9.816550e+05
# mean               0.135483       0.062327     1.760948e+05
# std                0.381677       0.433326     1.780350e+05
# min                0.000000       0.000000     0.000000e+00
# 25%                0.000000       0.000000     5.071600e+04
# 50%                0.000000       0.000000     1.136650e+05
# 75%                0.000000       0.000000     2.544460e+05
# max               12.000000      85.000000     9.999999e+06
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# count       9.816550e+05    9.816550e+05                9.816550e+05
# mean        5.143407e+04    2.208297e+04                4.347129e+04
# std         4.923899e+04    2.201333e+04                4.419870e+04
# min         0.000000e+00    0.000000e+00                0.000000e+00
# 25%         2.173600e+04    7.800000e+03                1.526900e+04
# 50%         3.856600e+04    1.540000e+04                3.277100e+04
# 75%         6.466900e+04    2.880000e+04                5.823300e+04
# max         3.408095e+06    1.090700e+06                2.101913e+06
#
#        revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# count     21825.000000            21825.000000             21825.000000
# mean      30655.418465              666.530584               670.530676
# std       23918.970521               42.726076                42.726460
# min           0.000000              540.000000               544.000000
# 25%       14271.000000              640.000000               644.000000
# 50%       24675.000000              665.000000               669.000000
# 75%       40366.000000              690.000000               694.000000
# max      304206.000000              845.000000               850.000000
#
#        sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# count            21825.000000      21825.000000      21825.000000
# mean                 0.653562          1.603940         11.405911
# std                  1.007022          1.747596          6.476826
# min                  0.000000          0.000000          0.000000
# 25%                  0.000000          0.000000          7.000000
# 50%                  0.000000          1.000000         10.000000
# 75%                  1.000000          3.000000         15.000000
# max                  6.000000         15.000000         73.000000
#
#        sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# count        21537.000000         21825.000000           21825.000000
# mean            60.395338             2.972829              12.584284
# std             24.527886             3.329978               8.022653
# min              0.000000             0.000000               0.000000
# 25%             43.000000             1.000000               7.000000
# 50%             62.600000             2.000000              11.000000
# 75%             79.900000             4.000000              17.000000
# max            172.700000            39.000000              96.000000
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# count                      21825.000000                        21825.000000
# mean                           0.043116                            0.079633
# std                            0.376429                            0.387298
# min                            0.000000                            0.000000
# 25%                            0.000000                            0.000000
# 50%                            0.000000                            0.000000
# 75%                            0.000000                            0.000000
# max                           18.000000                           11.000000
#
#        sec_app_mths_since_last_major_derog  deferral_term  hardship_amount  \
# count                          7541.000000         3004.0      3004.000000
# mean                             37.223578            3.0       139.645905
# std                              23.913957            0.0       118.037976
# min                               0.000000            3.0         0.640000
# 25%                              16.000000            3.0        48.722500
# 50%                              36.000000            3.0       109.745000
# 75%                              56.000000            3.0       195.347500
# max                             159.000000            3.0       893.050000
#
#        hardship_length  hardship_dpd  \
# count           3004.0   3004.000000
# mean               3.0     10.912450
# std                0.0     10.335562
# min                3.0      0.000000
# 25%                3.0      0.000000
# 50%                3.0     10.000000
# 75%                3.0     20.000000
# max                3.0     32.000000
#
#        orig_projected_additional_accrued_interest  \
# count                                 2579.000000
# mean                                   415.708406
# std                                    352.782675
# min                                      1.920000
# 25%                                    145.740000
# 50%                                    324.090000
# 75%                                    580.470000
# max                                   2679.150000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                     3004.000000                   3004.000000
# mean                     10853.407054                    185.329897
# std                       7498.772571                    197.700464
# min                         55.730000                      0.010000
# 25%                       4885.157500                     26.652500
# 50%                       9329.785000                    122.055000
# 75%                      15001.367500                    291.372500
# max                      40306.410000                   1247.480000
#
#        settlement_amount  settlement_percentage  settlement_term
# count        8630.000000            8630.000000      8630.000000
# mean         5273.266724              48.379779        10.655736
# std          3759.984557               8.915334         8.691919
# min            82.960000               0.550000         0.000000
# 25%          2376.600000              45.000000         1.000000
# 50%          4444.015000              45.295000        12.000000
# 75%          7190.120000              50.000000        18.000000
# max         30000.000000             521.350000       181.000000

# %% [markdown]
# corr = df.corr(method = 'spearman')

# %% [markdown]
# plt.figure(figsize = (10, 8))
# sns.heatmap(corr.abs(), cmap ='viridis' )
# plt.show()

# %% [markdown]
# #find highly correlated features
# new_corr = corr.abs()
# new_corr.loc[:,:] = np.tril(new_corr, k=-1) # below main lower triangle of an array
# new_corr = new_corr.stack().to_frame('correlation').reset_index().sort_values(by='correlation', ascending=False)

# %% [markdown]
# new_corr[new_corr.correlation > 0.6]

# %%
#Histogramas

# %%
numeric_features = df.select_dtypes(include=['int32', 'int64', 'float64']).columns

# %%
numeric_features
# Out:
# Index(['member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'fico_range_low',
#        'fico_range_high',
#        ...
#        'hardship_amount', 'hardship_length', 'hardship_dpd',
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'settlement_amount', 'settlement_percentage', 'settlement_term',
#        'test_set'],
#       dtype='object', length=112)

# %%
# Histogram with Kernel Density Estimate Plot (KDE)
# Source: https://stackoverflow.com/questions/43638851/pandas-histogram-plot-with-kde
def plot_histograms(df, columns):
    # keep total number of subplot
    k = len(df.columns)
    # n = number of chart columns
    n = columns
    m = (k - 1) // n + 1
    
    # Create figure
    fig, axes = plt.subplots(m, n, figsize=(n * 5, m * 3))

    # Iterate through columns, tracking the column name and 
    # which number we are at i. Within each iteration, plot
    for i, (name, col) in enumerate(df.iteritems()):
        r, c = i // n, i % n
        ax = axes[r, c]
        # the histogram
        col.hist(ax=ax)
        # kde = Kernel Density Estimate plot
        ax2 = col.plot.kde(ax=ax, secondary_y=True, title=name)
        ax2.set_ylim(0)

    # Use tight_layout() as an easy way to sharpen up the layout spacing
    fig.tight_layout()

# %%
# selecciono algunas como ejemplo, por ejemplo, los ID no hay que incluirlos nunca en el EDA
plot_histograms(df=df[['loan_amnt', 'funded_amnt', 'funded_amnt_inv',
       'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'fico_range_low',
       'fico_range_high']], columns=4)

# %%
sns.set(style="white")

# Compute the correlation matrix
corr = df[['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 
           'installment', 'annual_inc', 'dti', 'delinq_2yrs', 
           'fico_range_low','fico_range_high']].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bloque 2: selección de variables

# %% [markdown]
# # Bloque 3: modelado

# %%
import sklearn
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate, KFold

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, \
                            silhouette_score, recall_score, precision_score, make_scorer, \
                            roc_auc_score, f1_score, precision_recall_curve

from sklearn.metrics import accuracy_score, roc_auc_score, \
                            classification_report, confusion_matrix


from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression

# %%
#Combining numerical and categorical piepline into one big pipeline horizontally using ColumnTransformer
from sklearn.compose import ColumnTransformer

## No podemos utilizar TransformTargetRegression porque estamos en un modelo de clasificacion
# from 'Y' and 'N' to numeric values
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
# Leería los datos que ya los tendría preparados
df_selected = pd.read_csv('/Users/eduardo/Documents/CUNEF_ASIGNATURAS/MLEAR/practica0/data/raw/df_selected.csv')

# %%
df_selected.describe(include = 'all')
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv           term  \
# count   442335.000000  442335.000000    442335.000000  442335.000000
# unique            NaN            NaN              NaN            NaN
# top               NaN            NaN              NaN            NaN
# freq              NaN            NaN              NaN            NaN
# mean     14566.416856   14566.416856     14561.066882      42.140378
# std       8500.018979    8500.018979      8496.756229      10.472109
# min       1000.000000    1000.000000       900.000000      36.000000
# 25%       8000.000000    8000.000000      8000.000000      36.000000
# 50%      12500.000000   12500.000000     12500.000000      36.000000
# 75%      20000.000000   20000.000000     20000.000000      60.000000
# max      40000.000000   40000.000000     40000.000000      60.000000
#
#              int_rate    installment   grade sub_grade     emp_length  \
# count   442335.000000  442335.000000  442335    442335  442335.000000
# unique            NaN            NaN       7        35            NaN
# top               NaN            NaN       C        C1            NaN
# freq              NaN            NaN  124885     26548            NaN
# mean        13.255884     439.935320     NaN       NaN       5.767755
# std          4.471144     252.505972     NaN       NaN       3.722447
# min          5.320000      14.010000     NaN       NaN       0.000000
# 25%          9.990000     256.900000     NaN       NaN       2.000000
# 50%         12.990000     378.760000     NaN       NaN       6.000000
# 75%         15.990000     579.720000     NaN       NaN      10.000000
# max         30.990000    1714.540000     NaN       NaN      10.000000
#
#        home_ownership    annual_inc  verification_status    loan_status  \
# count          442335  4.423350e+05        442335.000000  442335.000000
# unique              4           NaN                  NaN            NaN
# top          MORTGAGE           NaN                  NaN            NaN
# freq           220364           NaN                  NaN            NaN
# mean              NaN  7.560386e+04             0.296696       0.219291
# std               NaN  6.504089e+04             0.456802       0.413767
# min               NaN  1.000000e+02             0.000000       0.000000
# 25%               NaN  4.560000e+04             0.000000       0.000000
# 50%               NaN  6.500000e+04             0.000000       0.000000
# 75%               NaN  9.000000e+04             1.000000       0.000000
# max               NaN  8.900060e+06             1.000000       1.000000
#
#                    purpose addr_state            dti    delinq_2yrs  \
# count               442335     442335  442335.000000  442335.000000
# unique                  14         51            NaN            NaN
# top     debt_consolidation         CA            NaN            NaN
# freq                268039      64858            NaN            NaN
# mean                   NaN        NaN      18.367815       0.338063
# std                    NaN        NaN       8.726000       0.909042
# min                    NaN        NaN       0.000000       0.000000
# 25%                    NaN        NaN      12.060000       0.000000
# 50%                    NaN        NaN      17.840000       0.000000
# 75%                    NaN        NaN      24.270000       0.000000
# max                    NaN        NaN     999.000000      39.000000
#
#         fico_range_low  fico_range_high       open_acc        pub_rec  \
# count    442335.000000    442335.000000  442335.000000  442335.000000
# unique             NaN              NaN            NaN            NaN
# top                NaN              NaN            NaN            NaN
# freq               NaN              NaN            NaN            NaN
# mean        693.172607       697.172704      11.800118       0.238668
# std          30.325347        30.325835       5.456944       0.632504
# min         660.000000       664.000000       1.000000       0.000000
# 25%         670.000000       674.000000       8.000000       0.000000
# 50%         685.000000       689.000000      11.000000       0.000000
# 75%         710.000000       714.000000      15.000000       0.000000
# max         845.000000       850.000000      90.000000      86.000000
#
#            revol_bal     revol_util      total_acc  initial_list_status  \
# count   4.423350e+05  442335.000000  442335.000000        442335.000000
# unique           NaN            NaN            NaN                  NaN
# top              NaN            NaN            NaN                  NaN
# freq             NaN            NaN            NaN                  NaN
# mean    1.629901e+04      53.091530      26.038145             0.562827
# std     2.232153e+04      23.843562      12.158772             0.496038
# min     0.000000e+00       0.000000       2.000000             0.000000
# 25%     5.992000e+03      35.400000      17.000000             0.000000
# 50%     1.115300e+04      53.400000      24.000000             1.000000
# 75%     1.985600e+04      71.300000      33.000000             1.000000
# max     2.560703e+06     892.300000     169.000000             1.000000
#
#         application_type  acc_open_past_24mths       mort_acc  \
# count      442335.000000         442335.000000  442335.000000
# unique               NaN                   NaN            NaN
# top                  NaN                   NaN            NaN
# freq                 NaN                   NaN            NaN
# mean            0.002258              4.795908       1.776111
# std             0.047470              3.143748       2.089641
# min             0.000000              0.000000       0.000000
# 25%             0.000000              3.000000       0.000000
# 50%             0.000000              4.000000       1.000000
# 75%             0.000000              6.000000       3.000000
# max             1.000000             53.000000      47.000000
#
#         pub_rec_bankruptcies      tax_liens  disbursement_method issue_month  \
# count          442335.000000  442335.000000        442335.000000      442335
# unique                   NaN            NaN                  NaN          12
# top                      NaN            NaN                  NaN         Oct
# freq                     NaN            NaN                  NaN       56111
# mean                0.147868       0.056475             0.000020         NaN
# std                 0.397284       0.419215             0.004511         NaN
# min                 0.000000       0.000000             0.000000         NaN
# 25%                 0.000000       0.000000             0.000000         NaN
# 50%                 0.000000       0.000000             0.000000         NaN
# 75%                 0.000000       0.000000             0.000000         NaN
# max                12.000000      85.000000             1.000000         NaN
#
#            issue_year  earliest_cr_year  credit_history
# count   442335.000000     442335.000000   442335.000000
# unique            NaN               NaN             NaN
# top               NaN               NaN             NaN
# freq              NaN               NaN             NaN
# mean      2014.599414       1998.159006       16.440408
# std          0.670304          7.464446        7.429709
# min       2014.000000       1944.000000        3.000000
# 25%       2014.000000       1994.000000       11.000000
# 50%       2015.000000       2000.000000       15.000000
# 75%       2015.000000       2003.000000       20.000000
# max       2017.000000       2014.000000       70.000000

# %% [markdown]
# Intencionadamente, no vamos a explicar detalladamente el código que viene a continuación, debes hacer el esfuerzo de intentar interpretarlo. Tómalo como ejemplo de código, nunca como algo a hacer copy/paste, porque no es un código que se puede extrapolar a cualquier proyecto.

# %%
def evaluate_model(ytest, ypred, ypred_proba = None):
    if ypred_proba is not None:
        print('ROC-AUC score of the model: {}'.format(roc_auc_score(ytest, ypred_proba[:, 1])))
    print('Accuracy of the model: {}\n'.format(accuracy_score(ytest, ypred)))
    print('Classification report: \n{}\n'.format(classification_report(ytest, ypred)))
    print('Confusion matrix: \n{}\n'.format(confusion_matrix(ytest, ypred)))

# %%
df_major = df_selected[df_selected.loan_status == 0]
df_minor = df_selected[df_selected.loan_status == 1]

# %%
df_minor_upsmapled = resample(df_minor, replace = True, n_samples = 358436, random_state = 12345)

# %%
df_minor_upsmapled = pd.concat([df_minor_upsmapled, df_major])

# %%
df_minor_upsmapled.loan_status.value_counts()
# Out:
# 1    358436
# 0    345335
# Name: loan_status, dtype: int64

# %%
df_minor_upsmapled.dtypes
# Out:
# loan_amnt               float64
# funded_amnt             float64
# funded_amnt_inv         float64
# term                      int64
# int_rate                float64
# installment             float64
# grade                    object
# sub_grade                object
# emp_length                int64
# home_ownership           object
# annual_inc              float64
# verification_status       int64
# loan_status               int64
# purpose                  object
# addr_state               object
# dti                     float64
# delinq_2yrs             float64
# fico_range_low          float64
# fico_range_high         float64
# open_acc                float64
# pub_rec                 float64
# revol_bal               float64
# revol_util              float64
# total_acc               float64
# initial_list_status       int64
# application_type          int64
# acc_open_past_24mths    float64
# mort_acc                float64
# pub_rec_bankruptcies    float64
# tax_liens               float64
# disbursement_method       int64
# issue_month              object
# issue_year                int64
# earliest_cr_year          int64
# credit_history            int64
# dtype: object

# %%
#Defining the steps in the numerical pipeline 
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

#Defining the steps in the categorical pipeline 
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
    
    
#Numerical features to pass down the numerical pipeline 
numeric_features = df_minor_upsmapled.select_dtypes(include=['int64', 'float64']).drop(['loan_status'], axis=1).columns

#Categrical features to pass down the categorical pipeline 
categorical_features = df_minor_upsmapled.select_dtypes(include=['object']).columns

# %%
X = df_minor_upsmapled.drop('loan_status', axis = 1)
Y = df_minor_upsmapled.loan_status

# %%
Y = LabelEncoder().fit_transform(Y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.25, random_state=12345)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
from sklearn.feature_selection import SelectFromModel, RFE
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
import category_encoders as ce
from sklearn.tree import plot_tree

# %%
list_columns_cat = list(xtrain.select_dtypes("object","category").columns)
list_others = (list(set(xtrain.columns)-set(list_columns_cat)))

# %%
ohe = ce.OneHotEncoder(cols = list_columns_cat)
model =ohe.fit(xtrain,ytrain)

# %%
xtrain_t = model.transform(xtrain, ytrain)
xtest_t = model.transform(xtest, ytest)

# %%
#Create decision tree classifier, we set a maxiumun number of nodes to 2 and max depth 7
clf =  DecisionTreeClassifier(max_depth=6)
clf = clf.fit(xtrain_t, ytrain)

# %%
clf
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
y_pred = clf.predict(xtest_t)

# %%
metrics.accuracy_score(ytest,y_pred)
# Out:
# 0.6598500650778946

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 text_representation = tree.export_text(clf)
#       2 print(text_representation)
#
# NameError: name 'tree' is not defined

# %%
with open("decision_tree.log","w") as fout:
    fout.write(text_representation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
#       1 with open("decision_tree.log","w") as fout:
# ----> 2     fout.write(text_representation)
#
# NameError: name 'text_representation' is not defined

# %%
fig = plt.figure(figsize = (60,30))
_ = tree.plot_tree(clf, filled = True, fontsize = 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 2>()
#       1 fig = plt.figure(figsize = (60,30))
# ----> 2 _ = tree.plot_tree(clf, filled = True, fontsize = 10)
#
# NameError: name 'tree' is not defined

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plot = plot_tree(
            decision_tree = clf,
            feature_names = pd.get_dummies(xtrain_t).columns.tolist(),
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )

# %% [markdown]
# que es la inestabilidad, es buena o mala y si tiene solucion

# %% [markdown]
# modelo SVM

# %%
model = SVC()
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', model)])
clf_fit = clf.fit(xtrain, ytrain)
